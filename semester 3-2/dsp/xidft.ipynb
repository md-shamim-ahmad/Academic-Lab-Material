# %%
import numpy as np
import matplotlib.pyplot as plt

Xk_str = input('Enter X(K) (space-separated values): ')
Xk = np.array([complex(x) for x in Xk_str.split()])

N = len(Xk)  # Get the number of elements in Xk

xn = np.zeros(N, dtype=complex)
k = np.arange(N)
for n in range(N):
    xn[n] = np.sum(np.exp(1j * 2 * np.pi * k * n / N) * Xk)

xn /= N

print('x(n) =')
print(xn)

plt.figure()
plt.stem(k, xn.real)
plt.xlabel('n')
plt.ylabel('Magnitude')
plt.title('IDFT OF A SEQUENCE')
plt.grid(True)
plt.show()
# Out:
# x(n) =
# [ 4.17647059+0.j         -0.28536095-0.03558392j -0.35240681-0.41377465j
#   0.44018862+0.70262262j  0.26007585+0.02898611j  0.11045187+0.05968002j
#  -0.07864054+0.09770379j  0.09768584-0.05558515j  0.21977084+0.15063364j
#   0.21977084-0.15063364j  0.09768584+0.05558515j -0.07864054-0.09770379j
#   0.11045187-0.05968002j  0.26007585-0.02898611j  0.44018862-0.70262262j
#  -0.35240681+0.41377465j -0.28536095+0.03558392j]
